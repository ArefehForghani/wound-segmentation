# %% [markdown]
# <a href="https://colab.research.google.com/github/ArefehForghani/wound-segmentation/blob/main/wound_segmention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/wound-segmentation')


# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/wound-segmentation

# %%
# !pip install tensorflow opencv-python numpy matplotlib scikit-learn pandas

# %%
# !python train.py --data_path data/wound_dataset/
# Out:
# 2025-12-28 21:34:51.421099: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766957691.463215    2570 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766957691.474400    2570 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766957691.500891    2570 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !pip install segmentation_models
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 5.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# The `deeplab.py` file has been updated again. Please re-run the training cell (`!python train.py --data_path data/wound_dataset/`) to see if the issue is resolved.
